# %%
import pandas  as pd
import os
from sklearn.metrics import classification_report

# %%
working_dir =  '../../../../data/annotation_consistency/human_kidney/'
misclassifed_spots_path = 'usually_misclassifed.csv'
gt_file = working_dir+'/PathologistAnnotations.csv'

# %%
correctly_classifed_by_model = 'correctly_classified.csv'
fixed_gt = 'Annotation_Fix.csv'

# %%
init_missclassified = pd.read_csv(os.path.join(working_dir, misclassifed_spots), index_col=0)
gt = pd.read_csv(gt_file, index_col=0)
correctly_classified = pd.read_csv(os.path.join(working_dir, correctly_classifed_by_model), index_col=0)
fixed_gt = pd.read_csv(os.path.join(working_dir, fixed_gt), index_col=0)

misclassified_spots = pd.read_csv(os.path.join(working_dir, misclassifed_spots_path), index_col=0)

# %%
changed_by_pathologist = pd.merge(misclassified_spots, fixed_gt, how='inner', left_index=True, right_index=True)
changed_by_pathologist
# Out:
#                                          Model Prediction  \
# Barcode
# AAGCACTAAGAAGGAG-1                                Tubules
# AGGAATCCGATGGTAT-1           mixed_1_tubules_interstitium
# AGGATACCTATTGGAA-1           mixed_1_tubules_interstitium
# ATAACTCGAAGTCCGC-1                                Tubules
# ATCAAGGAACGCATCG-1  mixed_3_glomeruli_tubuli_interstitium
# CACTCAGTCCAGCGGA-1                                Tubules
# CATTCTGTCTGCACTG-1           mixed_1_tubules_interstitium
# CCGACAATTGCAACAG-1           mixed_1_tubules_interstitium
# CCTAACAGTTATAGGA-1         mixed_2_glomeruli_interstitium
# CGAATGGAATCGTGAC-1                                Tubules
# CGCACGCCATAGGTAG-1                                Tubules
# CTACGAGTCGCCTCGG-1         mixed_2_glomeruli_interstitium
# CTTGGACAGTCGAGTC-1  mixed_3_glomeruli_tubuli_interstitium
# GAAGCTTCCGTAGCAA-1           mixed_1_tubules_interstitium
# GACCGTATAACGGAAC-1                                Tubules
# GACTTGTCCGAAGTTA-1           mixed_1_tubules_interstitium
# GAGGTACTTAGTGGTC-1                                Tubules
# GCCTAACGACGTTGAC-1           mixed_1_tubules_interstitium
# GCGTCTCACGAGTGGT-1           mixed_1_tubules_interstitium
# TAGTGATCGAGTCGAC-1           mixed_1_tubules_interstitium
# TGCACGACCGATTCTA-1         mixed_2_glomeruli_interstitium
# TGCCAGATTCCTCGAC-1                                Tubules
# TGTCAACACTTCAGTT-1                                Tubules
#
#                           Current Pathologist Annotations  \
# Barcode
# AAGCACTAAGAAGGAG-1           mixed_1_tubules_interstitium
# AGGAATCCGATGGTAT-1                                Tubules
# AGGATACCTATTGGAA-1                                Tubules
# ATAACTCGAAGTCCGC-1           mixed_1_tubules_interstitium
# ATCAAGGAACGCATCG-1                                Tubules
# CACTCAGTCCAGCGGA-1                                exclude
# CATTCTGTCTGCACTG-1                           Interstitium
# CCGACAATTGCAACAG-1                                Tubules
# CCTAACAGTTATAGGA-1  mixed_3_glomeruli_tubuli_interstitium
# CGAATGGAATCGTGAC-1           mixed_1_tubules_interstitium
# CGCACGCCATAGGTAG-1  mixed_3_glomeruli_tubuli_interstitium
# CTACGAGTCGCCTCGG-1                              Glomeruli
# CTTGGACAGTCGAGTC-1                                Tubules
# GAAGCTTCCGTAGCAA-1                                Tubules
# GACCGTATAACGGAAC-1                           Interstitium
# GACTTGTCCGAAGTTA-1                                Tubules
# GAGGTACTTAGTGGTC-1         mixed_2_glomeruli_interstitium
# GCCTAACGACGTTGAC-1                           Interstitium
# GCGTCTCACGAGTGGT-1                           Interstitium
# TAGTGATCGAGTCGAC-1                           Interstitium
# TGCACGACCGATTCTA-1           mixed_1_tubules_interstitium
# TGCCAGATTCCTCGAC-1           mixed_1_tubules_interstitium
# TGTCAACACTTCAGTT-1           mixed_1_tubules_interstitium
#
#                                            Annotation_Fix
# Barcode
# AAGCACTAAGAAGGAG-1  mixed_3_glomeruli_tubuli_interstitium
# AGGAATCCGATGGTAT-1     Interstitium_fibrosis_inflammation
# AGGATACCTATTGGAA-1     Interstitium_fibrosis_inflammation
# ATAACTCGAAGTCCGC-1  mixed_3_glomeruli_tubuli_interstitium
# ATCAAGGAACGCATCG-1           mixed_1_tubules_interstitium
# CACTCAGTCCAGCGGA-1                                exclude
# CATTCTGTCTGCACTG-1     Interstitium_fibrosis_inflammation
# CCGACAATTGCAACAG-1     Interstitium_fibrosis_inflammation
# CCTAACAGTTATAGGA-1  mixed_3_glomeruli_tubuli_interstitium
# CGAATGGAATCGTGAC-1  mixed_3_glomeruli_tubuli_interstitium
# CGCACGCCATAGGTAG-1           mixed_1_tubules_interstitium
# CTACGAGTCGCCTCGG-1  mixed_3_glomeruli_tubuli_interstitium
# CTTGGACAGTCGAGTC-1         mixed_2_glomeruli_interstitium
# GAAGCTTCCGTAGCAA-1     Interstitium_fibrosis_inflammation
# GACCGTATAACGGAAC-1           mixed_1_tubules_interstitium
# GACTTGTCCGAAGTTA-1     Interstitium_fibrosis_inflammation
# GAGGTACTTAGTGGTC-1           mixed_1_tubules_interstitium
# GCCTAACGACGTTGAC-1  mixed_3_glomeruli_tubuli_interstitium
# GCGTCTCACGAGTGGT-1     Interstitium_fibrosis_inflammation
# TAGTGATCGAGTCGAC-1     Interstitium_fibrosis_inflammation
# TGCACGACCGATTCTA-1  mixed_3_glomeruli_tubuli_interstitium
# TGCCAGATTCCTCGAC-1  mixed_3_glomeruli_tubuli_interstitium
# TGTCAACACTTCAGTT-1  mixed_3_glomeruli_tubuli_interstitium

# %%
correctly_classified
# Out:
#                                   Accepted Predictions
# Barcode
# AACAATGTGCTCCGAG-1                             Tubules
# AACCAAGACCAACTGA-1                             exclude
# AACCATAGATTCTGGC-1                             Tubules
# AACGACCGCTTGCGGT-1  Interstitium_fibrosis_inflammation
# AACGGCCGTACTTCCT-1                             Tubules
# ...                                                ...
# TGTAATCTAACATTCG-1                             Tubules
# TGTATGATCGTTAACC-1                             Tubules
# TGTCAGGTCGGCCAGC-1  Interstitium_fibrosis_inflammation
# TGTCCATGTATTCGCC-1                           Glomeruli
# TGTTGGTGCGCACGAG-1  Interstitium_fibrosis_inflammation
#
# [307 rows x 1 columns]

# %%
# make a Latex table with the results
# Name of a class, number of spots initally mislcaasied according to GT, number of spots those classfication is accepted by pathologist
# Group by class name to calculate statistics
misclassified_counts = init_missclassified['Model Prediction'].value_counts()
accepted_counts = correctly_classified['Accepted Predictions'].value_counts()
fixed_gt_counts = changed_by_pathologist['Model Prediction'].value_counts()
# Combine into a DataFrame for the LaTeX table
summary_df = pd.DataFrame({
    'Class Name': misclassified_counts.index,
    'Initially Misclassified': misclassified_counts.values,
    'Accepted by Pathologist': accepted_counts.reindex(misclassified_counts.index, fill_value=0).values,
    'Changed by Pathologist': fixed_gt_counts.reindex(misclassified_counts.index, fill_value=0).values
})



# add column percentage of accepted (on two decimal places)
summary_df['Percentage Change'] = ((summary_df['Accepted by Pathologist']+summary_df['Changed by Pathologist']) / summary_df['Initially Misclassified'] * 100).round(2)
summary_df
# Out:
#                               Class Name  Initially Misclassified  \
# 0                                Tubules                      385
# 1           mixed_1_tubules_interstitium                       78
# 2     Interstitium_fibrosis_inflammation                       57
# 3  mixed_3_glomeruli_tubuli_interstitium                       24
# 4                                exclude                       21
# 5         mixed_2_glomeruli_interstitium                       16
# 6                           Interstitium                       12
# 7                              Glomeruli                        9
# 8                             Hemorrhage                        4
#
#    Accepted by Pathologist  Changed by Pathologist  Percentage Change
# 0                      149                       9              41.04
# 1                       42                       9              65.38
# 2                       55                       0              96.49
# 3                       21                       2              95.83
# 4                       14                       0              66.67
# 5                        5                       3              50.00
# 6                       12                       0             100.00
# 7                        9                       0             100.00
# 8                        0                       0               0.00

# %%
# print total number and percentage of spots that are accepted by pathologist
total_accepted = summary_df['Accepted by Pathologist'].sum()
total_changed = total_accepted + summary_df['Changed by Pathologist'].sum()
total_misclassified = summary_df['Initially Misclassified'].sum()
percentage_accepted = total_accepted / total_misclassified * 100
print(f"Total number of spots accepted by pathologist: {total_accepted}")
print(f"Total number of spots changed by pathologist: {total_changed}")
print(f"Total number of spots initially misclassified: {total_misclassified}")
print(f"Percentage of spots accepted by pathologist: {percentage_accepted:.2f}%")
print(f"Percentage of spots changed by pathologist: {total_changed / total_misclassified * 100:.2f}%")
# Out:
# Total number of spots accepted by pathologist: 307
# Total number of spots changed by pathologist: 330
# Total number of spots initially misclassified: 606
# Percentage of spots accepted by pathologist: 50.66%
# Percentage of spots changed by pathologist: 54.46%

# %%
# generate a LaTeX table
print(summary_df.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#                            Class Name &  Initially Misclassified &  Accepted by Pathologist &  Changed by Pathologist &  Percentage Change \\
# \midrule
#                               Tubules &                      385 &                      149 &                       9 &              41.04 \\
#          mixed\_1\_tubules\_interstitium &                       78 &                       42 &                       9 &              65.38 \\
#    Interstitium\_fibrosis\_inflammation &                       57 &                       55 &                       0 &              96.49 \\
# mixed\_3\_glomeruli\_tubuli\_interstitium &                       24 &                       21 &                       2 &              95.83 \\
#                               exclude &                       21 &                       14 &                       0 &              66.67 \\
#        mixed\_2\_glomeruli\_interstitium &                       16 &                        5 &                       3 &              50.00 \\
#                          Interstitium &                       12 &                       12 &                       0 &             100.00 \\
#                             Glomeruli &                        9 &                        9 &                       0 &             100.00 \\
#                            Hemorrhage &                        4 &                        0 &                       0 &               0.00 \\
# \bottomrule
# \end{tabular}
# <ipython-input-13-a797b87fb44c>:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(summary_df.to_latex(index=False))
